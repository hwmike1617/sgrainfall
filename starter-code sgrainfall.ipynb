# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# ## Problem Statement
# __*This project aims to see whether can we rely on Singapore's weather climate alone to successfully grow our own vegetables?*__

# %% [markdown]
# ![urbanfarming.jpg](attachment:dc14703a-310f-425d-a997-4e24a333561b.jpg)
# Source:URA
#
# Malaysia accounts for 42% of the vegetables imports for Singapore (https://www.channelnewsasia.com/singapore/cna-explains-where-does-singapore-get-its-food-2709161).
# With the recent closure of the borders between Malaysia and Singapore due to the Covid-19 pandemic,
# and with the recent increase in the prices of vegetables in Malaysia due to the monsoon seasons, Singapore government is finding ways to increase our self-sustainability
# in producing our own vegetables (https://www.ura.gov.sg/Corporate/Resources/Ideas-and-Trends/feeding-the-city-growth-of-urban-agriculture). This is to reduce our heavy reliance on our neighbor for vegetables in the event of border closures or sudden increase in pricing of the vegetables.
#
# This project aims to help the vegetable farming and the horticulture community to see whether vegetable farming can thrive under Singapore weather alone? Or will the usage of other means such as hydroponic farming, UV LED lighting or irrigation system can further improve the efficacy of the vegetable farming?
#
#
# **The datasets used:**
#
# 1) rainfall-monthly-total.csv (provided by General Assembly).
# This dataset shows the monthly total rainfall from Jan-1982 till Aug-2022.
#
# 2) rainfall-monthly-number-of rain-days.csv (provided by General Assembly).
# This dataset shows the number of rainy days in a month from Jan-1982 till Aug-2022.
#
# 3) sunshine-duration-monthly-mean-daily-duration.csv (provided by NEA.gov.sg
# website https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration).
# This dataset shows the monthly mean daily sunshine duration(hours) from Jan-1982 till Nov-2022.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# 1) Singapore source of food. The article cited shows where a large supply of our vegetables come from.
#
#    https://www.channelnewsasia.com/singapore/cna-explains-where-does-singapore-get-its-food-2709161
#
# 2) Singapore urban farming to be more self-reliant. Singapore government is trying out rooftop farming with the help of residents to increase our vegetables production.
#
#    https://www.ura.gov.sg/Corporate/Resources/Ideas-and-Trends/feeding-the-city-growth-of-urban-agriculture
#
# 3) Amount of water requirements. The article recommends an inch of water per week which roughly translates to 4inches (101.6mm) per month.
#
#    https://www.creativevegetablegardener.com/watering-vegetable-garden/
#
# 4) Amount of Sunlight requirements. The article describes 6 to 8 hours of sunlight is recommended.
#
#    https://www.gardenary.com/blog/how-much-sun-does-a-vegetable-garden-need
#
# 5) Number of days required to grow vegetables. The number of days to grow leafy vegetables ranges from 1.5 to 3 months.
#
#    https://www.nparks.gov.sg/nparksbuzz/dec-issue-2021/gardening/growing-five-leafy-vegetables

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code: Function for calculating the mean values of the list of numbers.
def mean_values(my_list):
    return sum(my_list)/len(my_list)

# %%
lst=[1,2,3,4,5]
mean_values(lst)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code: Function to calculate the standard deviation of a list of numbers.
import math
def std_dev(my_list):
    total=0
    for i in my_list:
        total+=(i-mean_values(my_list))**2
    return math.sqrt(total/len(my_list))

# %%
std_dev(lst)
# Out:
# 1.4142135623730951

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from scipy.stats import linregress
from pylab import savefig
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# reading the total monthly rainfall
rainfall_vol=pd.read_csv('./data/rainfall-monthly-total.csv')

# %%
# checking the first 5 rows of rainfall_vol
rainfall_vol.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
# check for null values in rainfall_vol
rainfall_vol.isnull().sum()
# Out:
# month             0
# total_rainfall    0
# dtype: int64

# %%
# checking the info of rainfall_vol
rainfall_vol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   month           488 non-null    object
#  1   total_rainfall  488 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
# reading the monthly number of rainy days 
rainfall_days=pd.read_csv('./data/rainfall-monthly-number-of-rain-days.csv')

# %%
# checking the first 5 rows of rainfall_days
rainfall_days.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
# # check for null values in rainfall_days
rainfall_days.isnull().sum()
# Out:
# month               0
# no_of_rainy_days    0
# dtype: int64

# %%
# checking for info of rainfall_days
rainfall_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             488 non-null    object
#  1   no_of_rainy_days  488 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8+ KB

# %%
# reading monthly mean daily sunshine hours
mean_sunshine = pd.read_csv('./data/sunshine-duration-monthly-mean-daily-duration.csv')

# %%
# checking the first 5 rows of mean_sunshine
mean_sunshine.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
# checking for null values in mean_sunshine
mean_sunshine.isnull().sum()
# Out:
# month                0
# mean_sunshine_hrs    0
# dtype: int64

# %%
# checking for info on mean_sunshine
mean_sunshine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              491 non-null    object
#  1   mean_sunshine_hrs  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB

# %%
# merging three datasets (rainfall_vol, rainfall_days,mean_sunshine) together
sg_climate=rainfall_vol.merge(rainfall_days, how='left', left_on='month', 
                              right_on='month').merge(mean_sunshine, how='left', 
                              left_on='month', right_on='month')

# %%
# checking the first 5 rows of sg_climate
sg_climate.head()
# Out:
#      month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs
# 0  1982-01           107.1                10                5.6
# 1  1982-02            27.8                 5                7.6
# 2  1982-03           160.8                11                5.1
# 3  1982-04           157.0                14                4.7
# 4  1982-05           102.2                10                5.8

# %%
# check for null values in sg_climate
sg_climate.isnull().sum()
# Out:
# month                0
# total_rainfall       0
# no_of_rainy_days     0
# mean_sunshine_hrs    0
# dtype: int64

# %%
# converting month to datetime format
sg_climate['date']=pd.to_datetime(sg_climate['month'])

# %%
# split date to month and year format
sg_climate['year'] = sg_climate['date'].dt.year
sg_climate['month']=sg_climate['date'].dt.month

# %%
# check for sg_climate info
sg_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 487
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              488 non-null    int64
#  1   total_rainfall     488 non-null    float64
#  2   no_of_rainy_days   488 non-null    int64
#  3   mean_sunshine_hrs  488 non-null    float64
#  4   date               488 non-null    datetime64[ns]
#  5   year               488 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 26.7 KB

# %%
# changing the month from numeric to calender format
sg_climate['month'] = pd.to_datetime(sg_climate['month'], format='%m').dt.strftime('%b')

# %%
# checking the first 5 rows of the sg_climate where the month is in calender format
sg_climate.head()
# Out:
#   month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  year
# 0   Jan           107.1                10                5.6 1982-01-01  1982
# 1   Feb            27.8                 5                7.6 1982-02-01  1982
# 2   Mar           160.8                11                5.1 1982-03-01  1982
# 3   Apr           157.0                14                4.7 1982-04-01  1982
# 4   May           102.2                10                5.8 1982-05-01  1982

# %%
# exporting the cleaned data out
sg_climate.to_csv('./data/sg_climate_cleaned.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# #### Data Dictionary for the datasets chosen
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |total_rainfall|float|rainfall-monthly-total|Total rainfall in mm|
# |no_of_rainy_days|int|rainfall-monthly-number-of-days|Total number of rainy days in a month|
# |mean_sunshine_hours|float|sunshine-duration-monthly-mean-daily-duration|Monthly mean daily sunshine hours|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# sg_climate summary statistics
sg_climate.describe()
# Out:
#        total_rainfall  no_of_rainy_days  mean_sunshine_hrs         year
# count      488.000000        488.000000         488.000000   488.000000
# mean       177.163730         14.061475           5.688320  2001.836066
# std        113.916029          4.947394           1.205705    11.752660
# min          0.200000          1.000000           2.700000  1982.000000
# 25%         93.850000         11.000000           4.800000  1992.000000
# 50%        159.450000         14.000000           5.700000  2002.000000
# 75%        238.075000         18.000000           6.500000  2012.000000
# max        765.900000         27.000000           9.300000  2022.000000

# %%
# creating sd dictionary comprehension for standard deviation
sd={'rainfall_monthly_total': std_dev(sg_climate['total_rainfall']),
    'no_of_rainy_days':std_dev(sg_climate['no_of_rainy_days']),
    'mean_sunshine_hours':std_dev(sg_climate['mean_sunshine_hrs'])}

# %%
# checking the standard deviation dictionary
sd
# Out:
# {'rainfall_monthly_total': 113.79925170470057,
#  'no_of_rainy_days': 4.9423221913224085,
#  'mean_sunshine_hours': 1.2044686452879794}

# %%
# highest top 5 months for total rainfall in year 1990
sg_climate[sg_climate['year']==1990].sort_values(by='total_rainfall', ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 104   Sep           204.5                17                5.1 1990-09-01
# 107   Dec           201.1                16                5.5 1990-12-01
# 106   Nov           180.4                17                4.6 1990-11-01
# 100   May           180.1                11                6.5 1990-05-01
# 96    Jan           147.4                13                5.3 1990-01-01
#
#      year
# 104  1990
# 107  1990
# 106  1990
# 100  1990
# 96   1990

# %%
# lowest bottom 5 months for total rainfall in year 1990
sg_climate[sg_climate['year']==1990].sort_values(by='total_rainfall').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 97    Feb            24.1                 8                8.9 1990-02-01
# 99    Apr            52.4                10                6.3 1990-04-01
# 105   Oct            56.4                12                5.9 1990-10-01
# 98    Mar            94.2                 4                8.3 1990-03-01
# 101   Jun           112.6                 9                6.3 1990-06-01
#
#      year
# 97   1990
# 99   1990
# 105  1990
# 98   1990
# 101  1990

# %%
# highest top 5 months for total rainfall in year 2000
sg_climate[sg_climate['year']==2000].sort_values(by='total_rainfall', ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 226   Nov           385.7                21                3.7 2000-11-01
# 219   Apr           311.6                20                5.3 2000-04-01
# 216   Jan           275.2                14                4.0 2000-01-01
# 218   Mar           238.3                15                5.8 2000-03-01
# 217   Feb           237.8                18                5.8 2000-02-01
#
#      year
# 226  2000
# 219  2000
# 216  2000
# 218  2000
# 217  2000

# %%
# lowest bottom 5 months for total rainfall in year 2000 
sg_climate[sg_climate['year']==2000].sort_values(by='total_rainfall').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 224   Sep            81.1                12                6.2 2000-09-01
# 220   May            96.8                10                6.8 2000-05-01
# 223   Aug           113.5                18                5.1 2000-08-01
# 222   Jul           116.1                12                6.5 2000-07-01
# 225   Oct           120.9                14                4.0 2000-10-01
#
#      year
# 224  2000
# 220  2000
# 223  2000
# 222  2000
# 225  2000

# %%
# highest top 5 months for total rainfall in year 2010
sg_climate[sg_climate['year']==2010].sort_values(by='total_rainfall', ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 342   Jul           298.5                18                4.6 2010-07-01
# 346   Nov           278.8                21                5.0 2010-11-01
# 341   Jun           240.5                19                5.1 2010-06-01
# 338   Mar           238.0                11                6.1 2010-03-01
# 347   Dec           181.4                14                3.6 2010-12-01
#
#      year
# 342  2010
# 346  2010
# 341  2010
# 338  2010
# 347  2010

# %%
# lowest bottom 5 months for total rainfall in year 2010
sg_climate[sg_climate['year']==2010].sort_values(by='total_rainfall').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 337   Feb             6.3                 4                8.8 2010-02-01
# 336   Jan            69.5                10                7.1 2010-01-01
# 344   Sep           121.5                13                5.7 2010-09-01
# 340   May           157.5                17                6.5 2010-05-01
# 343   Aug           158.4                16                5.4 2010-08-01
#
#      year
# 337  2010
# 336  2010
# 344  2010
# 340  2010
# 343  2010

# %%
# highest top 5 months total rainfall for year 2020
sg_climate[sg_climate['year']==2020].sort_values(by='total_rainfall', ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 460   May           255.6                16                5.7 2020-05-01
# 467   Dec           253.2                20                5.2 2020-12-01
# 461   Jun           233.8                21                4.3 2020-06-01
# 466   Nov           220.6                19                4.0 2020-11-01
# 459   Apr           188.0                12                7.1 2020-04-01
#
#      year
# 460  2020
# 467  2020
# 461  2020
# 466  2020
# 459  2020

# %%
# lowest bottom 5 months total rainfall for year 2020
sg_climate[sg_climate['year']==2020].sort_values(by='total_rainfall').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 457   Feb            65.0                 8                8.3 2020-02-01
# 465   Oct            78.8                16                4.3 2020-10-01
# 456   Jan            88.4                 6                7.1 2020-01-01
# 463   Aug           103.4                12                6.4 2020-08-01
# 458   Mar           108.8                 8                7.6 2020-03-01
#
#      year
# 457  2020
# 465  2020
# 456  2020
# 463  2020
# 458  2020

# %% [markdown]
# **Answer:**
#
# September and February has the highest and lowest total rainfall for year 1990 respectively.
#
# November and September has the highest and lowest total rainfall for year 2000 respectively.
#
# July and February has the highest and lowest total rainfall for year 2010 respectively.
#
# May and February has the highest and lowest total rainfall for year 2020 respectively.

# %%
# checking the year for highest total rainfall within the date range of analysis
sg_climate.loc[sg_climate['total_rainfall']==sg_climate['total_rainfall'].max()]
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 299   Dec           765.9                22                3.2 2006-12-01
#
#      year
# 299  2006

# %%
# checking the year for highest total rainfall within the date range of analysis using head()
sg_climate.sort_values(by='total_rainfall',ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 299   Dec           765.9                22                3.2 2006-12-01
# 468   Jan           692.8                17                4.2 2021-01-01
# 239   Dec           609.0                20                4.5 2001-12-01
# 264   Jan           600.9                13                6.7 2004-01-01
# 60    Jan           568.6                16                4.0 1987-01-01
#
#      year
# 299  2006
# 468  2021
# 239  2001
# 264  2004
# 60   1987

# %%
# checking the year for lowest total rainfall within the date range of analysis
sg_climate.loc[sg_climate['total_rainfall']==sg_climate['total_rainfall'].min()]
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 385   Feb             0.2                 1                8.8 2014-02-01
#
#      year
# 385  2014

# %%
# checking the year for lowest total rainfall within the date range of analysis using head()
sg_climate.sort_values(by='total_rainfall').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 385   Feb             0.2                 1                8.8 2014-02-01
# 469   Feb             1.0                 2                8.2 2021-02-01
# 13    Feb             5.6                 2                9.3 1983-02-01
# 410   Mar             6.2                 6                8.0 2016-03-01
# 337   Feb             6.3                 4                8.8 2010-02-01
#
#      year
# 385  2014
# 469  2021
# 13   1983
# 410  2016
# 337  2010

# %% [markdown]
# Answer: Year 2006 and 2014 has the highest and lowest total rainfall for the date range of analysis

# %%
# month/s with the highest number of rainy days in year 1990
sg_climate.mask(sg_climate['year']!=1990).dropna().sort_values(by='no_of_rainy_days'
                ,ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 104   Sep           204.5              17.0                5.1 1990-09-01
# 106   Nov           180.4              17.0                4.6 1990-11-01
# 107   Dec           201.1              16.0                5.5 1990-12-01
# 96    Jan           147.4              13.0                5.3 1990-01-01
# 103   Aug           146.6              13.0                5.8 1990-08-01
#
#        year
# 104  1990.0
# 106  1990.0
# 107  1990.0
# 96   1990.0
# 103  1990.0

# %%
# month/s with the lowest number of rainy days in year 1990
sg_climate.mask(sg_climate['year']!=1990).dropna().sort_values(by='no_of_rainy_days').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 98    Mar            94.2               4.0                8.3 1990-03-01
# 97    Feb            24.1               8.0                8.9 1990-02-01
# 101   Jun           112.6               9.0                6.3 1990-06-01
# 99    Apr            52.4              10.0                6.3 1990-04-01
# 100   May           180.1              11.0                6.5 1990-05-01
#
#        year
# 98   1990.0
# 97   1990.0
# 101  1990.0
# 99   1990.0
# 100  1990.0

# %%
# month/s with the highest number of rainy days in year 2000
sg_climate.mask(sg_climate['year']!=2000).dropna().sort_values(by='no_of_rainy_days'
                ,ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 226   Nov           385.7              21.0                3.7 2000-11-01
# 219   Apr           311.6              20.0                5.3 2000-04-01
# 217   Feb           237.8              18.0                5.8 2000-02-01
# 223   Aug           113.5              18.0                5.1 2000-08-01
# 227   Dec           236.0              18.0                4.2 2000-12-01
#
#        year
# 226  2000.0
# 219  2000.0
# 217  2000.0
# 223  2000.0
# 227  2000.0

# %%
# month/s with the lowest number of rainy days in year 2000
sg_climate.mask(sg_climate['year']!=2000).dropna().sort_values(by='no_of_rainy_days').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 220   May            96.8              10.0                6.8 2000-05-01
# 222   Jul           116.1              12.0                6.5 2000-07-01
# 224   Sep            81.1              12.0                6.2 2000-09-01
# 216   Jan           275.2              14.0                4.0 2000-01-01
# 225   Oct           120.9              14.0                4.0 2000-10-01
#
#        year
# 220  2000.0
# 222  2000.0
# 224  2000.0
# 216  2000.0
# 225  2000.0

# %%
# month/s with the highest number of rainy days in year 2010
sg_climate.mask(sg_climate['year']!=2010).dropna().sort_values(by='no_of_rainy_days'
                ,ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 346   Nov           278.8              21.0                5.0 2010-11-01
# 341   Jun           240.5              19.0                5.1 2010-06-01
# 339   Apr           158.5              18.0                6.2 2010-04-01
# 342   Jul           298.5              18.0                4.6 2010-07-01
# 340   May           157.5              17.0                6.5 2010-05-01
#
#        year
# 346  2010.0
# 341  2010.0
# 339  2010.0
# 342  2010.0
# 340  2010.0

# %%
# month/s with the lowest number of rainy days in year 2010
sg_climate.mask(sg_climate['year']!=2010).dropna().sort_values(by='no_of_rainy_days').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 337   Feb             6.3               4.0                8.8 2010-02-01
# 336   Jan            69.5              10.0                7.1 2010-01-01
# 338   Mar           238.0              11.0                6.1 2010-03-01
# 344   Sep           121.5              13.0                5.7 2010-09-01
# 347   Dec           181.4              14.0                3.6 2010-12-01
#
#        year
# 337  2010.0
# 336  2010.0
# 338  2010.0
# 344  2010.0
# 347  2010.0

# %%
# month/s with the highest number of rainy days in year 2020
sg_climate.mask(sg_climate['year']!=2020).dropna().sort_values(by='no_of_rainy_days'
                ,ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 462   Jul           140.8              22.0                5.7 2020-07-01
# 461   Jun           233.8              21.0                4.3 2020-06-01
# 467   Dec           253.2              20.0                5.2 2020-12-01
# 466   Nov           220.6              19.0                4.0 2020-11-01
# 464   Sep           150.2              18.0                4.8 2020-09-01
#
#        year
# 462  2020.0
# 461  2020.0
# 467  2020.0
# 466  2020.0
# 464  2020.0

# %%
# month/s with the lowest number of rainy days in year 2020
sg_climate.mask(sg_climate['year']!=2020).dropna().sort_values(by='no_of_rainy_days').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 456   Jan            88.4               6.0                7.1 2020-01-01
# 457   Feb            65.0               8.0                8.3 2020-02-01
# 458   Mar           108.8               8.0                7.6 2020-03-01
# 459   Apr           188.0              12.0                7.1 2020-04-01
# 463   Aug           103.4              12.0                6.4 2020-08-01
#
#        year
# 456  2020.0
# 457  2020.0
# 458  2020.0
# 459  2020.0
# 463  2020.0

# %% [markdown]
# **Answer:**
#
# For the year 1990, September and November have the same highest number of rainy days, whereas March has the lowest number of rainy days.
#
# For the year 2000, November and May has the highest and lowest number of rainy days respectively.
#
# For the year 2010, November and February has the highest and lowest number of rainy days respectively.
#
# For the year 2020, July and January has the highest and lowest number of rainy days respectively.

# %%
# checking the year for highest number of rainy days within the date range of analysis
sg_climate.loc[sg_climate['no_of_rainy_days']==sg_climate['no_of_rainy_days'].max()]
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 442   Nov           169.6                27                3.8 2018-11-01
#
#      year
# 442  2018

# %%
# checking the year for highest number of rainy days within the date range of analysis using head()
sg_climate.sort_values(by='no_of_rainy_days',ascending=False).head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 442   Nov           169.6                27                3.8 2018-11-01
# 432   Jan           287.0                25                4.1 2018-01-01
# 430   Nov           268.6                24                4.2 2017-11-01
# 475   Aug           293.6                24                4.8 2021-08-01
# 251   Dec           255.0                24                4.8 2002-12-01
#
#      year
# 442  2018
# 432  2018
# 430  2017
# 475  2021
# 251  2002

# %%
# checking the year for lowest number of rainy days within the date range of analysis
sg_climate.loc[sg_climate['total_rainfall']==sg_climate['total_rainfall'].min()]
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 385   Feb             0.2                 1                8.8 2014-02-01
#
#      year
# 385  2014

# %%
# checking the year for lowest number of rainy days within the date range of analysis using head()
sg_climate.sort_values(by='no_of_rainy_days').head()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 385   Feb             0.2                 1                8.8 2014-02-01
# 49    Feb            26.7                 2                7.2 1986-02-01
# 469   Feb             1.0                 2                8.2 2021-02-01
# 14    Mar            18.6                 2                8.9 1983-03-01
# 13    Feb             5.6                 2                9.3 1983-02-01
#
#      year
# 385  2014
# 49   1986
# 469  2021
# 14   1983
# 13   1983

# %% [markdown]
# **Answer:**
# Year 2018 and 2014 has the highest and lowest number of rainy days for the date range of analysis

# %%
# checking the IQR  for total rainfall from summary statistics
q1=93.085
q3=238.075
iqr=q3-q1
# setting the upper and lower bounds for total rainfall data
upper = q3+(1.5*iqr)
lower = q1-(1.5*iqr)

# %%
# masking the total rainfall data within the upper and lower bounds
sg_climate.mask((sg_climate['total_rainfall']>=lower)&(sg_climate['total_rainfall']<=upper)).dropna()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 11    Dec           494.1              21.0                3.3 1982-12-01
# 25    Feb           470.4              19.0                4.1 1984-02-01
# 60    Jan           568.6              16.0                4.0 1987-01-01
# 94    Nov           508.4              20.0                5.4 1989-11-01
# 119   Dec           492.3              19.0                3.0 1991-12-01
# 130   Nov           474.3              18.0                3.7 1992-11-01
# 131   Dec           502.7              23.0                3.4 1992-12-01
# 203   Dec           463.4              22.0                3.1 1998-12-01
# 239   Dec           609.0              20.0                4.5 2001-12-01
# 264   Jan           600.9              13.0                6.7 2004-01-01
# 299   Dec           765.9              22.0                3.2 2006-12-01
# 311   Dec           468.6              20.0                4.5 2007-12-01
# ...

# %% [markdown]
# **Answer:** The outlier months for total rainfall for date range analysis are: Dec-1982, Feb-1984, Jan-1987, Nov-1989, Dec-1991, Nov-1992, Dec-1992, December-2001, Jan-2004, Dec-2006, Dec-2007, Jan-2011, Jan-2021.

# %%
# checking the IQR  for number of rainy days from summary statistics
q1_rainy=11
q3_rainy=18
iqr_rainy=q3_rainy-q1_rainy
# setting the upper and lower bounds for number of rainy days data
upper_rainy = q3_rainy+(1.5*iqr_rainy)
lower_rainy = q1_rainy-(1.5*iqr_rainy)

# %%
# masking the number of rainy days data within the upper and lower bounds
sg_climate.mask((sg_climate['no_of_rainy_days']>=lower_rainy)&(sg_climate['no_of_rainy_days']<=upper_rainy)).dropna()
# Out:
# Empty DataFrame
# Columns: [month, total_rainfall, no_of_rainy_days, mean_sunshine_hrs, date, year]
# Index: []

# %% [markdown]
# **Answer:** There are no outliers for number of rainy days data.

# %%
# checking the IQR  for mean sunshine hours from summary statistics
q1_sun=4.8
q3_sun=6.5
iqr_sun=q3_sun-q1_sun
# setting the upper and lower bounds for mean sunshine hours data
upper_sun = q3_sun+(1.5*iqr_sun)
lower_sun = q1_sun-(1.5*iqr_sun)

# %%
# masking the mean sunshine hours data within the upper and lower bounds
sg_climate.mask((sg_climate['mean_sunshine_hrs']>=lower_sun)&(sg_climate['mean_sunshine_hrs']<=upper_sun)).dropna()
# Out:
#     month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  \
# 13    Feb             5.6               2.0                9.3 1983-02-01
# 61    Feb            86.9               7.0                9.2 1987-02-01
# 277   Feb             8.4               3.0                9.1 2005-02-01
# 445   Feb            31.6               5.0                9.2 2019-02-01
#
#        year
# 13   1983.0
# 61   1987.0
# 277  2005.0
# 445  2019.0

# %% [markdown]
# **Answer:** The outlier months for total rainfall for date range analysis are: Feb-1982, Feb-1987, Feb-2005, Feb-2019.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %% [markdown]
# ### 1. Seaborn Heatmap Correlation

# %%
# Compute the correlation matrix without the month and year columns
corr = sg_climate.drop(columns=['month','year']).corr()

# %%
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, vmax=.3, center=0, linewidths=0.2, 
                cbar_kws={"shrink": .5}).set_title('Mean Sunshine vs Total Rainfall vs Rainy Days', fontsize=16);

# %% [markdown]
# #### $\color{red}{\text{Heatmap Analysis:}}$
#
# **Daily Mean Sunshine** is inversely correlated to **Monthly No. of Rainy Days** and **Monthly Total Rainfall**.
#
# **Monthly No. of Rainy Days** is correlated to **Monthly Total Rainfall**

# %% [markdown]
# ### 2. Distribution: Histogram

# %% [markdown]
# #### *Monthly Daily Mean Sunshine Histogram*

# %%
# Histogram plotting for Daily Mean Sunshine
sg_climate.hist('mean_sunshine_hrs')
plt.title('Distribution Table of Monthly Daily Mean Sunshine', size=16)
plt.xlabel('Mean Hours', size=12)
plt.ylabel('No. of Months', size=12);

# %% [markdown]
# #### $\color{red}{\text{Monthly Daily Mean Sunshine Histogram Analysis:}}$
# The histogram is Centered Distribution with the most frequently occurences between 5 to 6 hours.

# %% [markdown]
# #### *Monthy Total Rainfall Histogram*

# %%
# Histogram plotting for Monthly Total Rainfall
sg_climate.hist('total_rainfall')
plt.title('Distribution Table of Monthly Total Rainfall in mm', size=16)
plt.xlabel('Total Rainfall in mm', size=12)
plt.ylabel('No. of Months', size=12);

# %%
# checking the number of times the total rainfall falls below 100mm
total=len(sg_climate[sg_climate['total_rainfall']<100])
print(f'The number of times the total rainfall falls below 100mm is {total} times within the date range of analysis.')
# Out:
# The number of times the total rainfall falls below 100mm is 127 times within the date range of analysis.

# %% [markdown]
# #### $\color{red}{\text{Monthly Total Rainfall Histogram Analysis:}}$
# The Monthly Total Rainfall is Right Skewed Distribution with most of the monthly total rainfall between 0 to 300mm.
# Note that there were about 127 months throughout the date range of analysis of records that monthly total rainfall is below 100mm.

# %% [markdown]
# #### *Monthly Number of Rainy Days Histogram*

# %%
# Histogram plotting for Monthly Number of Rainy Days
sg_climate.hist('no_of_rainy_days')
plt.title('Distribution Table of Monthly Number of Rainy Days', size=16)
plt.xlabel('Days', size=12)
plt.ylabel('No. of Months', size=12);

# %% [markdown]
# #### $\color{red}{\text{Monthly Number of Rainy Days Histogram Analysis:}}$
# The histogram is Centered Distribution with the most frequently occurences at 15 days.

# %% [markdown]
# ### 3. Boxplot

# %% [markdown]
# #### *Monthly Mean Sunshine Boxplot*

# %%
sg_climate.boxplot(column = 'mean_sunshine_hrs', by = 'year', figsize=(24, 12))
plt.title('Mean Sunshine Hours Boxplot', size=25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=18)
plt.ylabel('Mean Sunshine Hours', fontsize=22)
plt.xlabel('Year', fontsize=22)
plt.tight_layout()

# %% [markdown]
# #### $\color{red}{\text{Mean Sunshine Hours Boxplot Analysis:}}$
# From the Mean Sunshine Hours Boxplot, it can be seen from Year 2015 the median of the
# Mean Sunshine Hours going above Daily Mean Sunshine of 6 hours, with the median being lowest in Year 2001 and highest in Year 2019. This indicates that from Year 2015, there is a slight increment in the median of the Mean Sunshine Hours experienced in Singapore.
#
# The IQR does not show any pattern of changes over the years. The largest range occurs in Year 1983.
#
# There are outliers in 1985, 1990, 1993, 2001, 2002, 2005, 2010, 2012, 2014, 2017 and 2022.

# %% [markdown]
# #### *Total Rainfall Boxplot*

# %%
sg_climate.boxplot(column = 'total_rainfall', by = 'year', figsize=(24, 12))
plt.title('Total Rainfall Boxplot', size=25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=18)
plt.ylabel('Total Rainfall', fontsize=22)
plt.xlabel('Year', fontsize=22)
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Total Rainfall Boxplot Analysis:}}$
# From the Total Rainfall Boxplot, it can be seen the median of the Total Rainfall
# hovers between 100 to 200mm, with the median being lowest in Year 2019 and highest in Year 2013.
#
# The IQR does not show any pattern of changes over the years. The largest range occurs in Year 1992.
#
# There are no outliers in 1983,1986,1998,1990,1992-1996,1999-2000,2002,2005,2007-2009,2012-2014,2020 and 2022.

# %% [markdown]
# #### *Number of Rainy Days Boxplot*

# %%
sg_climate.boxplot(column = 'no_of_rainy_days', by = 'year', figsize=(24,12))
plt.title('No.of Rainy Days Boxplot', size=25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=18)
plt.ylabel('No. of Rainy Days', fontsize=22)
plt.xlabel('Year', fontsize=22)
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{No. of Rainy Days Boxplot Analysis:}}$
# From the No. of Rainy Days Boxplot, it can be seen the median of the No. of
# Rainy Days goes from below 15 days to hovering above 15 days from Year 2007, with the median No. of Rainy Days
# being lowest in Year 1997 and highest in Year 2017.
#
# The IQR does not show any pattern of changes over the years. The largest range occurs in Year 2014.
#
# There are outliers in 1982,1986,1988,1997,2002,2007,2010,2016,2021 and 2022.

# %% [markdown]
# ### 4. Scatterplot

# %% [markdown]
# #### *Monthly Daily Mean Sunshine Correlation*

# %%
# scatterplots for daily mean sunshine Correlation
figure, axes = plt.subplots(1, 2, sharex=True, figsize=(13,5))

# scatterplot for total rainfall
sns.scatterplot(ax=axes[0],data=sg_climate, x='mean_sunshine_hrs', y='total_rainfall')
axes[0].set_title('Monthly Total Rainfall vs Monthly Daily Mean Sunshine', fontsize=13)
axes[0].set_ylabel('Monthly Total Rainfall in mm')
axes[0].set_xlabel('Daily Mean Sunshine(hr)')

# scatterplot for no. of rainy days
sns.scatterplot(ax=axes[1],data=sg_climate, x='mean_sunshine_hrs', y='no_of_rainy_days')
axes[1].set_title('No. of Rainy Days vs Monthly Daily Mean Sunshine', fontsize=13)
axes[1].set_ylabel('Monthly No. of Rainy Days')
axes[1].set_xlabel('Daily Mean Sunshine(hr)')

plt.show()
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Monthly Total Rainfall and Monthly Daily Mean Sunshine Analysis:}}$
# As can be seen from the scatterplots, Monthly Daily Mean Sunshine is inversely correlated to both the Monthly Total Rainfall and No. of Rainy Days.

# %% [markdown]
# #### *Monthly Total Rainfall and No. of Rainy Days Correlation*

# %%
# scatterplot total rainfall and rainy days correlation
plt.figure(figsize=(13,7))
sns.scatterplot(data=sg_climate, x='total_rainfall', y='no_of_rainy_days')
plt.title('No. of Rainy Days vs Monthly Total Rainfall', fontsize=16)
plt.xlabel('Monthly Total Rainfall')
plt.ylabel('No.of Rainy Days')

plt.show()
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Monthly Total Rainfall and Monthly Daily Mean Sunshine Analysis:}}$
# Monthly Total Rainfall is correlated to No. of Rainy Days as can be seen from the scatterplot.

# %% [markdown]
# ### 5. Additional Plots -Vegetable Farming Analysis

# %% [markdown]
# **The 3 conditions to ensure productive vegetable farming:**
#
# 1) Between 6 to 8 hours of sunlight.
# 2) Monthly Total Rainfall of 100mm and above.
# 3) Number of days for vegetables growing is 1.5 to 3 months.
#
# The aim now is look through the datasets and infer whether Singapore weather climate is suitable for the efficacy of vegetable farming.

# %% [markdown]
# #### 5.1 Inferential Statistics for Total Rainfall and Daily Mean Sunshine

# %% [markdown]
# The following barplot visualizations of both means of Daily Mean Sunshine and Total Rainfall by months throughout the different years will help give a better understanding of how feasible is Singapore weather climate for vegetable farming by months.

# %%
# barplot of mean of daily mean sunshine hours by month
vals=sg_climate.groupby('month')['mean_sunshine_hrs'].mean()
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
# re-order the months in ascending order
vals.index = pd.CategoricalIndex(vals.index, categories=months, ordered=True)
vals = vals.sort_index()
# plotting the barplots
sg_climate.groupby('month')['mean_sunshine_hrs'].mean().reindex(
    pd.Series(pd.date_range("01-01-1982", freq="M", periods=12)).dt.strftime("%b")).plot(kind="bar",
    figsize=(10, 6),color=["red" if i < 6 else "blue" for i in vals])

plt.grid()
plt.xlabel("Month", size=12)
plt.ylabel("Ave. of Daily Mean Sunshine Hours", size=12)
plt.title("Average of Daily Mean Sunshine Hours by Month", size=16, y=1.05)

# manually setting the labels for different color bar plots
blue_patch = mpatches.Patch(color='blue', label='Daily Mean Sunshine>=6')
red_patch = mpatches.Patch(color='red', label='Daily Mean Sunshine<6')
plt.legend(handles=[red_patch, blue_patch])
plt.show()
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Monthly Average Daily Mean Sunshine Barplot Analysis:}}$
#
# The months of February, March, April and July have at least a mean of Daily Mean Sunshine Hours of 6 hours over the range of date analysis as can be infer from the above barplot. The lowest Daily Mean Sunshine Hours is in December, whereas the highest is in February.

# %%
# barplot of mean of total rainfall by month
sg_climate.groupby('month')['total_rainfall'].mean().reindex(
    pd.Series(pd.date_range("01-01-1982", freq="M", periods=12)).dt.strftime("%b")).plot(kind="bar",
    figsize=(10, 6),color='orange', label='Ave. of Total Rainfall')

plt.grid()
plt.xlabel("Month", size=12)
plt.ylabel("Ave. of Total Rainfall", size=12)
plt.legend()
plt.title("Average of Total Rainfall by Month", size=16, y=1.05)
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Monthly Average Total Rainfall Barplot Analysis:}}$
#
# All the months have a average of Total Rainfall above 100mm over the range of date analysis as can be infer from the above barplot. The lowest average Total Rainfall is in February, whereas the highest is in December.
#
# ---

# %% [markdown]
# Next, we look into the number of occurrences of months that have conducive environment for vegetable farming. A conducive environment is defined here as having Daily Mean Sunshine Hours of at least 6 hours and Total Rainfall at least 100mm.

# %%
# setting the condition for conduciveness of vegetable farming
condition=[((sg_climate['mean_sunshine_hrs']<6) | (sg_climate['total_rainfall']<100)),
           ~((sg_climate['mean_sunshine_hrs']<6) | (sg_climate['total_rainfall']<100))]

# %%
# setting 2 values of 'conducive' and 'not conducive'
values=['not conducive','conducive']

# %%
# creating the condition with the correct selected value for each row
sg_climate['condition']=np.select(condition, values)

# %%
sg_climate['condition'].value_counts()
# Out:
# not conducive    388
# conducive        100
# Name: condition, dtype: int64

# %% [markdown]
# ***Note*** *There are only 100 data points which are conducive environment and 388 data points that are not conducive environment.*

# %%
# one hot encoding for the condition column
sg_climate_cond=pd.get_dummies(sg_climate, columns=['condition'])

# %%
sg_climate_cond.head()
# Out:
#   month  total_rainfall  no_of_rainy_days  mean_sunshine_hrs       date  year  \
# 0   Jan           107.1                10                5.6 1982-01-01  1982
# 1   Feb            27.8                 5                7.6 1982-02-01  1982
# 2   Mar           160.8                11                5.1 1982-03-01  1982
# 3   Apr           157.0                14                4.7 1982-04-01  1982
# 4   May           102.2                10                5.8 1982-05-01  1982
#
#    condition_conducive  condition_not conducive
# 0                    0                        1
# 1                    0                        1
# 2                    0                        1
# 3                    0                        1
# 4                    0                        1

# %%
# checking the value counts for the months within the date range of analysis
sg_climate_cond['month'].value_counts()
# Out:
# Jan    41
# Feb    41
# Mar    41
# Apr    41
# May    41
# Jun    41
# Jul    41
# Aug    41
# Sep    40
# Oct    40
# Nov    40
# Dec    40
# Name: month, dtype: int64

# %%
# plotting the occurrences on a monthly basis throughout the whole date of analysis
sg_climate_cond['month'].value_counts().reindex(
    pd.Series(pd.date_range("01-01-1982", freq="M", periods=12)).dt.strftime("%b")).plot(kind="bar",
    figsize=(10, 6),color='r',label='Not Conducive')
sg_climate_cond.groupby('month')['condition_conducive'].sum().reindex(
    pd.Series(pd.date_range("01-01-1982", freq="M", periods=12)).dt.strftime("%b")).plot(kind="bar",
    figsize=(10, 6),color='g',label='Conducive')

plt.grid()
plt.xlabel("Month", size=12)
plt.ylabel("Occurrences", size=12)
plt.ylim(0,50)
plt.legend()
plt.title("Occurrences by Month", size=16, y=1.05)
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Occurrences Barplot Analysis:}}$
#
# From the Occurrences Barplot, it can be seen that the number of occurrences of not conducive months outweigh that of conducive environments throughout the whole date range of analysis. For the whole date range of analysis (which is roughly 40 years), the months of September and October have at most 5 occurences of conducive environments for vegetable farming whereas the months of November and December have none.

# %% [markdown]
# #### 5.2 Inferential Statistics for No. of Rainy Days and Daily Mean Sunshine

# %% [markdown]
# The following visualizations depict the relationship between both means of Daily Mean Sunshine and  No. of Rainy Days throughout the different years. These visualizations will help give a better understanding of how the No. of Rainy Days in a month can affect vegetable farming.

# %%
# get coeffs of linear fit
slope, intercept, r_value, p_value, std_err = linregress(sg_climate['mean_sunshine_hrs'], 
                                              sg_climate['no_of_rainy_days'])
# scatterplot for no. of rainy days vs daily mean sunshine with regression line
sns.regplot(data=sg_climate, x='mean_sunshine_hrs', y='no_of_rainy_days',  
            scatter_kws={'label':'Orig. Data','color': 'blue'}, 
            line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope,intercept),'color':'red'})

plt.title('No. of Rainy Days vs Monthly Daily Mean Sunshine')
plt.ylabel('Monthly No. of Rainy Days')
plt.xlabel('Daily Mean Sunshine(hr)')
plt.legend()
plt.grid()
plt.show()
plt.tight_layout();

# %% [markdown]
# ***Note*** The equation of the Regression Line is y=-2.8x + 29.9

# %%
# checking the predicted monthly no. of rainy days given minimum daily mean sunshine =6hrs
# using the regression line equation
x=6
y=(-2.8*x)+29.9
print(f'The predicted Monthly No. of Rainy Days: {round(y)} rainy days for {x} hours of Daily Mean Sunshine.')
# Out:
# The predicted Monthly No. of Rainy Days: 13 rainy days for 6 hours of Daily Mean Sunshine.

# %%
# re-order the months in ascending order
vals.index = pd.CategoricalIndex(vals.index, categories=months, ordered=True)
vals = vals.sort_index()

# barplot of mean no.of rainy days by month
sg_climate_cond.groupby('month')['no_of_rainy_days'].mean().reindex(
    pd.Series(pd.date_range("01-01-1982", freq="M", periods=12)).dt.strftime("%b")).plot(kind="bar",
    figsize=(10, 6),color='y', label='Ave. No. of Rainy Days')

plt.grid()
plt.xlabel("Month", size=12)
plt.ylabel("Ave. No. of Rainy Days", size=12)
# plot horizontal line at y=13 rainy days which corresponds to daily mean sunshine of 6 hours
plt.axhline(y=13, color='black', label='y=13 rainy days')
plt.legend()
plt.title("Average No. of Rainy Days by Month", size=16, y=1.05)
plt.tight_layout();

# %% [markdown]
# #### $\color{red}{\text{Monthly Average No. of Rainy Days Barplot Analysis:}}$
#
# The black line at y=13 rainy days corresponds to the minimal condition of Daily Mean Sunshine Hours of 6 hours in order for vegetables to grow.
#
# From the previous No. of Rainy Days vs Monthly Daily Mean Sunshine Scatterplot, it can be seen that as the number of rainy days goes above 13 rainy days, the Daily Mean Sunshine hours will fall below 6 hours which is not conducive for vegetable farming.
#
# From the Monthly Average No. of Rainy Days Barplot, only February and March have lesser than 13 rainy days. This implies that only February and March have Daily Mean Sunshine above 6 hours for the whole date range of analysis.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ### Conclusions
# To achieve Singapore goverment's intitiative on self-reliance on vegetable produce, we need to be able to grow vegetables throughout the whole year without any disruptions. In addition, it takes 1.5 to 3 months to acheive successful farming of various types of of the vegetables.
#
# 1. There are 4 months (February, March, April and July) from the Average Daily Mean Sunshine Hours by Month Barplot that have Daily Mean Sunshine hours of at least 6 hours. The rest of the year do not meet the requirements of minimum 6 hours of Daily Mean Sunshine hours for proper vegetable farming.
# 2. The Occurrences Barplot shows that occurrences of a good conducive month within the date range of analysis is significantly much lesser to that of not conducive month.
# 3. The Average No. of Rainy Days by Month Barplot shows that only February and March have Daily Mean Sunshine of at least 6 hours, whereas the rest of the year have less than 6 hours of Daily Mean Sunshine.
#
# From the above points, it can be seen that only February and March are the conducive months to grow vegetables. We are unable to grow vegetables constantly throughout the whole year. This is not effective in increasing our own vegetable production.
#
# In addition, from the Occurences Barplot, the occurrences of good conducive February and March are much lesser than that of the not conducive February and March for the whole date range of analysis. So there is a high probablity February and March can also become not conducive for vegetable farming in the future.
#
# Moreover, only 2 out of 12 months are good for vegetables farming. Some vegetables require more than 3 months to grow successfully.
#
# It is therefore reasonable to conclude that we **CANNOT** rely on Singapore Weather alone to successfully grow our own vegetables throughout the whole year.

# %% [markdown]
# ### Recommendations
# Proper UV lighting system installation is required to provide constant amount (6-8 hours) of daily sunshine hours throughout the whole year. This will increase the efficacy of vegetable farming without any disruptions from the weather.
#
# There is a need to erect proper irrigation and reservoir systems. The reservoir will stored the rain water from those months with high number of rainy days. In turn, the reservoir will use the irrigation system to supply water to the vegetables. This will ensure that the vegetables will receive constant water supply throughout the whole year even in those months that have low number of rainy days.
#
# A proper drainage system is also required for months that have a high number of rainy days. If the excessive water are trapped in the ground and not drained away properly, this can lead to poor soil aeration and temperature which can affect the vegetables' growth. Poor drainage can also cause pestilences which can destroy the vegetables. ([*source*](https://indiaagronet.com/indiaagronet/water_management/CONTENTS/Excess%20Water.htm))
